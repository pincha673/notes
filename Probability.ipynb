# %% [markdown]
# <a href="https://colab.research.google.com/github/pincha673/notes/blob/main/Probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Probability***

# %%
from scipy import stats

# %%
stats.norm.cdf(680,711,29)
# Out:
# 0.14254260383881612

# %%
stats.norm.cdf(60,50,5)
# Out:
# 0.9772498680518208

# %%
stats.norm.cdf(70,60,10)
# Out:
# 0.8413447460685429

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded=files. upload()
# Out:
#      <input type="file" id="files-c70b2c32-3c0d-469a-9b9a-7338593d7176" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c70b2c32-3c0d-469a-9b9a-7338593d7176">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
beml_df = pd.read_csv('BEML.csv')

# %%
beml_df.head()
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              101651.0          1157.18
# 1               59504.0           676.47
# 2              128908.0          1482.84
# 3              117871.0          1352.98
# 4              170063.0          1971.42

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-551f089d-3a4e-4754-a8bc-0674d669f62c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-551f089d-3a4e-4754-a8bc-0674d669f62c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
glaxo_df=pd.read_csv('GLAXO.csv')

# %%
glaxo_df.head()
# Out:
#          Date     Open     High      Low    Last    Close  \
# 0  2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1  2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2  2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3  2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4  2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                9365.0           151.74
# 1               38148.0           622.58
# 2               36519.0           595.09
# 3               12809.0           211.00
# 4               28035.0           459.11

# %%
beml_df= beml_df[['Date', 'Close']]
glaxo_df= glaxo_df[['Date', 'Close']]  # for selecting only two columns

# %%
beml_df
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# ...          ...      ...
# 1734  2016-12-26   950.25
# 1735  2016-12-27   975.70
# 1736  2016-12-28   974.40
# 1737  2016-12-29   986.05
# 1738  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
glaxo_df
# Out:
#             Date    Close
# 0     2010-01-04  1625.65
# 1     2010-01-05  1616.80
# 2     2010-01-06  1638.50
# 3     2010-01-07  1648.70
# 4     2010-01-08  1639.80
# ...          ...      ...
# 1734  2016-12-26  2723.50
# 1735  2016-12-27  2701.75
# 1736  2016-12-28  2702.15
# 1737  2016-12-29  2727.90
# 1738  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %% [markdown]
# chaining of many codes.# to change the Date into index and change the date from object to datetime

# %%
glaxo_df=glaxo_df.set_index(pd.DatetimeIndex(glaxo_df['Date'])).drop('Date',axis=1)

# %%
beml_df=beml_df.set_index(pd.DatetimeIndex(beml_df['Date'])).drop('Date',axis=1)

# %%
glaxo_df.head()
# Out:
#               Close
# Date
# 2010-01-04  1625.65
# 2010-01-05  1616.80
# 2010-01-06  1638.50
# 2010-01-07  1648.70
# 2010-01-08  1639.80

# %%
beml_df.head()
# Out:
#               Close
# Date
# 2010-01-04  1135.60
# 2010-01-05  1134.60
# 2010-01-06  1139.60
# 2010-01-07  1144.15
# 2010-01-08  1144.05

# %%
beml_df.dtypes
# Out:
# Close    float64
# dtype: object

# %% [markdown]
# # for *graphs*

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
plt.plot(glaxo_df.Close);
plt.xlabel('Time');
plt.ylabel('Close Price');

# %%
glaxo_df['gain'] = glaxo_df.Close.pct_change(periods = 1) # to get gain column
beml_df['gain'] = beml_df.Close.pct_change(periods = 1)

# %%
glaxo_df['loss'] = glaxo_df.Close.pct_change(periods=2)   # to grt the loss column
beml_df ['loss'] = beml_df.Close.pct_change(periods=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
glaxo_df
# Out:
#               Close      gain      loss
# Date
# 2010-01-05  1616.80 -0.005444       NaN
# 2010-01-06  1638.50  0.013422       NaN
# 2010-01-07  1648.70  0.006225  0.019730
# 2010-01-08  1639.80 -0.005398  0.000793
# 2010-01-11  1629.45 -0.006312 -0.011676
# ...             ...       ...       ...
# 2016-12-26  2723.50 -0.001283  0.003685
# 2016-12-27  2701.75 -0.007986 -0.009259
# 2016-12-28  2702.15  0.000148 -0.007839
# 2016-12-29  2727.90  0.009529  0.009679
# 2016-12-30  2729.80  0.000697  0.010233
#
# [1738 rows x 3 columns]

# %%
beml_df
# Out:
#               Close      gain      loss
# Date
# 2010-01-05  1134.60 -0.000881       NaN
# 2010-01-06  1139.60  0.004407       NaN
# 2010-01-07  1144.15  0.003993  0.008417
# 2010-01-08  1144.05 -0.000087  0.003905
# 2010-01-11  1137.00 -0.006162 -0.006249
# ...             ...       ...       ...
# 2016-12-26   950.25 -0.021924 -0.013957
# 2016-12-27   975.70  0.026782  0.004272
# 2016-12-28   974.40 -0.001332  0.025414
# 2016-12-29   986.05  0.011956  0.010608
# 2016-12-30  1000.60  0.014756  0.026888
#
# [1738 rows x 3 columns]

# %%
glaxo_df = glaxo_df.dropna()  # 1st column whic are nan are removed

# %%
glaxo_df
# Out:
#               Close      gain      loss
# Date
# 2010-01-07  1648.70  0.006225  0.019730
# 2010-01-08  1639.80 -0.005398  0.000793
# 2010-01-11  1629.45 -0.006312 -0.011676
# 2010-01-12  1583.85 -0.027985 -0.034120
# 2010-01-13  1571.30 -0.007924 -0.035687
# ...             ...       ...       ...
# 2016-12-26  2723.50 -0.001283  0.003685
# 2016-12-27  2701.75 -0.007986 -0.009259
# 2016-12-28  2702.15  0.000148 -0.007839
# 2016-12-29  2727.90  0.009529  0.009679
# 2016-12-30  2729.80  0.000697  0.010233
#
# [1736 rows x 3 columns]

# %%
beml_df = beml_df.dropna()

# %%
beml_df
# Out:
#               Close      gain      loss
# Date
# 2010-01-07  1144.15  0.003993  0.008417
# 2010-01-08  1144.05 -0.000087  0.003905
# 2010-01-11  1137.00 -0.006162 -0.006249
# 2010-01-12  1143.65  0.005849 -0.000350
# 2010-01-13  1142.25 -0.001224  0.004617
# ...             ...       ...       ...
# 2016-12-26   950.25 -0.021924 -0.013957
# 2016-12-27   975.70  0.026782  0.004272
# 2016-12-28   974.40 -0.001332  0.025414
# 2016-12-29   986.05  0.011956  0.010608
# 2016-12-30  1000.60  0.014756  0.026888
#
# [1736 rows x 3 columns]

# %%
glaxo_df   # nan column
# Out:
#               Close      gain
# Date
# 2010-01-04  1625.65       NaN
# 2010-01-05  1616.80 -0.005444
# 2010-01-06  1638.50  0.013422
# 2010-01-07  1648.70  0.006225
# 2010-01-08  1639.80 -0.005398
# ...             ...       ...
# 2016-12-26  2723.50 -0.001283
# 2016-12-27  2701.75 -0.007986
# 2016-12-28  2702.15  0.000148
# 2016-12-29  2727.90  0.009529
# 2016-12-30  2729.80  0.000697
#
# [1739 rows x 2 columns]

# %%
beml_df
# Out:
#               Close      gain
# Date
# 2010-01-04  1135.60       NaN
# 2010-01-05  1134.60 -0.000881
# 2010-01-06  1139.60  0.004407
# 2010-01-07  1144.15  0.003993
# 2010-01-08  1144.05 -0.000087
# ...             ...       ...
# 2016-12-26   950.25 -0.021924
# 2016-12-27   975.70  0.026782
# 2016-12-28   974.40 -0.001332
# 2016-12-29   986.05  0.011956
# 2016-12-30  1000.60  0.014756
#
# [1739 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (8, 5));
plt.plot(beml_df.gain);
plt.xlabel('Time');
plt.ylabel('gain');

# %%
glaxo_df = glaxo_df.dropna()  # to drop the 1st column in gain

# %%
glaxo_df
# Out:
#               Close      gain
# Date
# 2010-01-05  1616.80 -0.005444
# 2010-01-06  1638.50  0.013422
# 2010-01-07  1648.70  0.006225
# 2010-01-08  1639.80 -0.005398
# 2010-01-11  1629.45 -0.006312
# ...             ...       ...
# 2016-12-26  2723.50 -0.001283
# 2016-12-27  2701.75 -0.007986
# 2016-12-28  2702.15  0.000148
# 2016-12-29  2727.90  0.009529
# 2016-12-30  2729.80  0.000697
#
# [1738 rows x 2 columns]

# %%
beml_df = beml_df.dropna()

# %%
beml_df
# Out:
#               Close      gain
# Date
# 2010-01-05  1134.60 -0.000881
# 2010-01-06  1139.60  0.004407
# 2010-01-07  1144.15  0.003993
# 2010-01-08  1144.05 -0.000087
# 2010-01-11  1137.00 -0.006162
# ...             ...       ...
# 2016-12-26   950.25 -0.021924
# 2016-12-27   975.70  0.026782
# 2016-12-28   974.40 -0.001332
# 2016-12-29   986.05  0.011956
# 2016-12-30  1000.60  0.014756
#
# [1738 rows x 2 columns]

# %%
import seaborn as sn

# %%
plt.figure(figsize=(10,5))                   #to get the distribution graph pf Galxo with sub plot 1,2,1 and with subtitle
plt.subplot(1,2,1)
plt.suptitle ('Distribution', fontsize = 17)
sn.distplot (glaxo_df.gain,label='Galxo');
plt.xlabel('gain')
plt.ylabel ("Density");
plt.legend();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sn

# %%
plt.subplot(1,2,2)
sn.distplot(beml_df.gain, label = 'BEML');

plt.xlabel('gain')
plt.ylabel('Density');
plt.legend();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print ('Mean:', round(glaxo_df.gain.mean(), 4))             # mean and standard deviation of galxo 
print ('Standar Deviation:', round(glaxo_df.gain.std(), 4))
# Out:
# Mean: 0.0004
# Standar Deviation: 0.0134

# %%
print('Mean:', round(beml_df.gain.mean(), 4))         # mean and standard deviation of Beml
print ('Standar Deviation:', round(beml_df.gain.std(),4))
# Out:
# Mean: 0.0003
# Standar Deviation: 0.0264

# %% [markdown]
# # **Excerise**

# %%
#probability of making 2% loss or higher in Beml

# %%
stats.norm.cdf (-0.02,
loc=beml_df.gain.mean(),
scale=beml_df.gain.std())
# Out:
# 0.22170880207617266

# %%
#probability of making 2% gain or higher in Beml

# %%
1-stats.norm.cdf (0.02,
loc=beml_df.gain.mean(),
scale=beml_df.gain.std())
# Out:
# 0.22780675886438917

# %% [markdown]
# # Probability of making 2% gain in Galxo

# %%
1-stats.norm.cdf(0.02,0.0004,0.0134)
# Out:
# 0.07177658173190637

# %%
stats.norm.cdf(-0.02,0.0004,0.0134)   #probabiltiy of making 2% loss in galxo
# Out:
# 0.06395593743937553
